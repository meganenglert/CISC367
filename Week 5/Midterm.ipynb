# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("C:\\Users\\megan\\Desktop\\CISC367\\Student_Assessment_Performance.csv")
data2 = pd.read_csv("C:\\Users\\megan\\Desktop\\CISC367\\Delaware_Public_Education_Organization_Directory.csv")

# %%
data1.head()
types = data2[["District Code","District Type"]]
types = types.drop_duplicates()
combined = pd.merge(types, data1)
combined.drop_duplicates("District Code")
# Out:
#         District Code   District Type  School Year  \
# 0                   0  Not Applicable         2015
# 3646               10         Regular         2015
# 17430              13         Regular         2015
# 30624              15         Regular         2015
# 38915              16         Regular         2015
# 46228              17         Regular         2015
# 60678              18         Regular         2015
# 70737              23         Regular         2015
# 80383              24         Regular         2015
# 90182              29         Regular         2015
# 107409             31         Regular         2015
# 127994             32         Regular         2015
# 154755             33         Regular         2015
# 188936             36         Regular         2015
# 208681             34         Regular         2015
# 224157             35         Regular         2015
# 231580             37         Regular         2015
# ...
